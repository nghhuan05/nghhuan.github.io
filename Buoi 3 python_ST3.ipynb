# %% [markdown]
# <a href="https://colab.research.google.com/github/nghhuan05/nghhuan.github.io/blob/hh-pages/Buoi%203%20python_ST3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mục mới

# %% [markdown]
# Data structure

# %%
x = ["apple", "banana", "cherry"] #list
print (x, type(x))
x = ("apple", "banana", "cherry") #tuple
print (x, type(x))
x = {"name" : "Tom", "age" : 20} #dict
print (x, type(x))
x = {"apple", "banana", "cherry"} #set
print (x, type(x))
# Out:
# ['apple', 'banana', 'cherry'] <class 'list'>
# ('apple', 'banana', 'cherry') <class 'tuple'>
# {'name': 'Tom', 'age': 20} <class 'dict'>
# {'apple', 'cherry', 'banana'} <class 'set'>

# %%
x = [60, 70, 80, 90]
print(len(x))
print(x[0])
print(x[1])
print(x[-1])
print(x[1:3])
print(x[-2:-4:-1])
print(x[:-1], x[:],x[::-1])
# Out:
# 4
# 60
# 70
# 90
# [70, 80]
# [80, 70]
# [60, 70, 80] [60, 70, 80, 90] [90, 80, 70, 60]

# %%
animals = {'cat', 'dog'}
print("animals")
print('cat' in animals)
print('fish' in animals)
animals.add('fish')
print("animals")
print('fish' in animals)
print(len(animals))
animals.add('cat’)
print(len(animals))
animals.remove('cat')
print(len(animals))

# %%
s = "Hom nay la thu hai"
print (len(s), list(s))
print (len(set(list(s)))), list (set(list(s)))
# Out:
# 18 ['H', 'o', 'm', ' ', 'n', 'a', 'y', ' ', 'l', 'a', ' ', 't', 'h', 'u', ' ', 'h', 'a', 'i']
# 12
# (None, ['y', 'l', 'm', 'i', ' ', 'h', 'H', 'o', 'a', 'u', 't', 'n'])

# %%
s = "Hom nay la thu hai"
d_cnt =()
for ci in list(s):
if d_cnt.get(ci) is None :
  s_cnt[ci] = 1
  else:
    d_cnt = d_cnt[ci] + 1

# %%
expenses = [72.50, 80.75, 50.00, 90.25]
total_expenses = sum(expenses)
print("Total expenses:", total_expenses)
# Out:
# Total expenses: 293.5

# %%
accounts = (("Cash", 1001), ("Accounts Receivable", 1002),("Inventory", 1003))
for account in accounts:
 print("Account name:", account[0], "Account number:", account[1])
# Out:
# Account name: Cash Account number: 1001
# Account name: Accounts Receivable Account number: 1002
# Account name: Inventory Account number: 1003

# %% [markdown]
# Python Control Logic and Loops

# %%
a = 5
b = 2
print (a < b)
# Out:
# False

# %%
score = 80
if score >=60 :
  print("Pass")
score = 80
if score >=60 :
  print("Pass")
else:
  print("Fail")
# Out:
# Pass
# Pass

# %%
score = 95
if score >= 90 :
 print("A")
elif score >=60 :
 print("Pass")
else:
 print("Fail")
# Out:
# A

# %%
score = 90
grade = ""
if score >=90:
 grade = "A"
elif score >= 80:
 grade = "B"
elif score >= 70:
 grade = "C"
elif score >= 60:
 grade = "D"
else:
 grade = "E"
print(grade)
# Out:
# A

# %%
for i in range(1,6):
 print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(1,10):
 for j in range(1,10):
  print(i, ' * ' , j , ' = ', i*j)
print ("-"*50)
# Out:
# 1  *  1  =  1
# 1  *  2  =  2
# 1  *  3  =  3
# 1  *  4  =  4
# 1  *  5  =  5
# 1  *  6  =  6
# 1  *  7  =  7
# 1  *  8  =  8
# 1  *  9  =  9
# 2  *  1  =  2
# 2  *  2  =  4
# 2  *  3  =  6
# 2  *  4  =  8
# 2  *  5  =  10
# 2  *  6  =  12
# 2  *  7  =  14
# 2  *  8  =  16
# 2  *  9  =  18
# 3  *  1  =  3
# 3  *  2  =  6
# 3  *  3  =  9
# 3  *  4  =  12
# 3  *  5  =  15
# 3  *  6  =  18
# 3  *  7  =  21
# 3  *  8  =  24
# 3  *  9  =  27
# 4  *  1  =  4
# 4  *  2  =  8
# 4  *  3  =  12
# 4  *  4  =  16
# 4  *  5  =  20
# 4  *  6  =  24
# 4  *  7  =  28
# 4  *  8  =  32
# 4  *  9  =  36
# 5  *  1  =  5
# 5  *  2  =  10
# 5  *  3  =  15
# 5  *  4  =  20
# 5  *  5  =  25
# 5  *  6  =  30
# 5  *  7  =  35
# 5  *  8  =  40
# 5  *  9  =  45
# 6  *  1  =  6
# 6  *  2  =  12
# 6  *  3  =  18
# 6  *  4  =  24
# 6  *  5  =  30
# 6  *  6  =  36
# 6  *  7  =  42
# 6  *  8  =  48
# 6  *  9  =  54
# 7  *  1  =  7
# 7  *  2  =  14
# 7  *  3  =  21
# 7  *  4  =  28
# 7  *  5  =  35
# 7  *  6  =  42
# 7  *  7  =  49
# 7  *  8  =  56
# 7  *  9  =  63
# 8  *  1  =  8
# 8  *  2  =  16
# 8  *  3  =  24
# 8  *  4  =  32
# 8  *  5  =  40
# 8  *  6  =  48
# 8  *  7  =  56
# 8  *  8  =  64
# 8  *  9  =  72
# 9  *  1  =  9
# 9  *  2  =  18
# 9  *  3  =  27
# 9  *  4  =  36
# 9  *  5  =  45
# 9  *  6  =  54
# 9  *  7  =  63
# 9  *  8  =  72
# 9  *  9  =  81
# --------------------------------------------------

# %%
# Python Function def
# indentation for blocks. four spaces
def getfv(pv, r, n):
 fv = pv * ((1 + (r)) ** n)
 return fv
fv = getfv(100, 0.1, 7)
print(round(fv, 2))
# Out:
# 194.87

# %%
# How much is your $100 worth after 7 years?
fv = 100 * 1.1 ** 7
print('fv = ', round(fv, 2))
# output = 194.87
# Out:
# fv =  194.87

# %%
# Python Function def
# indentation for blocks. four spaces
def getfv(pv, r, n):
 fv = pv * ((1 + (r)) ** n)
 return fv
fv = getfv(100, 0.1, 7)
print(round(fv, 2))
# Out:
# 194.87

# %%
# Python class
class MyClass:
 x = 5
c1 = MyClass()
print(c1.x)
# Out:
# 5

# %%
class Person:
 def __init__(self, name, age):
  self.name = name
  self.age = age

p1 = Person("Alan", 20)

print(p1.name)
print(p1.age)
# Out:
# Alan
# 20

# %% [markdown]
# PYTHON MODULES

# %%
# mymodule.py
def greeting(name):
 print("Hello, " + name)

# %%
# mymodule.py
def greeting(name):
 print("Hello, " + name)

greeting("Alan")
# Out:
# Hello, Alan
